# %% [markdown]
# <H3> Part I: Creating, Reading and Writing </H3>
#
# Creating DataFrame and Series objects as well as reading data file

# %% [markdown]
# <I>all external datasets used in this notebook are sourced from [Kaggle](https://www.kaggle.com/code/residentmario/creating-reading-and-writing/data) <I>

# %%
import pandas as pd
pd.set_option('display.max_rows',5)
print("setup complete")
# Out:
# setup complete

# %% [markdown]
# Creating DataFrame 'fruits'

# %%
fruits = pd.DataFrame({'Apples':[30],'Bananas':[21]})
fruits
# Out:
#    Apples  Bananas
# 0      30       21

# %% [markdown]
# Creating DataFrame 'fruit_sales' with indexes

# %%
fruit_sales = pd.DataFrame({'Apples':[35,31],
                            'Bananas':[43,22]}, 
                            index=['2017sales','2018sales'])
fruit_sales
# Out:
#            Apples  Bananas
# 2017sales      35       43
# 2018sales      31       22

# %% [markdown]
# Creating a Series for ingredients

# %% [markdown]
# Flour     4 cups  <br>
# Milk       1 cup<br>
# Eggs     2 large<br>
# Spam       1 can<br>
# Name: Dinner, dtype: object

# %%
ingredients = pd.Series(['4 cups','1 cup','2 large','1 can'],
                        index=['Flour','Milk','Eggs','Spam'],
                        name='Dinner', dtype='object')
ingredients
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %% [markdown]
# Reading the following csv dataset of wine reviews into a DataFrame called reviews

# %%
reviews = pd.read_csv("../Data/winemag-data_first150k.csv", index_col=0)

reviews
#learned df.shape and df.head()
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# ...        ...                                                ...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# ...                                      ...     ...    ...
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province     region_1 region_2             variety  \
# 0               California  Napa Valley     Napa  Cabernet Sauvignon
# ...

# %% [markdown]
# Making a DF and saving it to disk as a csv file

# %%
animals = pd.DataFrame({'cows':[20,30],'goats':[21,25]},
                       index=['Year 1','Year 2'])
animals
# Out:
#         cows  goats
# Year 1    20     21
# Year 2    30     25

# %%
animals.to_csv("myData/cows_goats.csv", index=True)

check = pd.read_csv("myData/cows_goats.csv", index_col=0)
check.head()
# Out:
#         cows  goats
# Year 1    20     21
# Year 2    30     25

# %% [markdown]
# <h3>Part II: Indexing, Selecting and Assigning</h3>
# Selecting specific values of a pandas DataFrame or Series to work on/relevant data points

# %%
reviewsII = pd.read_csv("../Data/winemag-data-130k-v2.csv", index_col=0)
reviewsII.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# Selecting the column "description" and assigning the value to "desc" variable

# %%
desc = reviewsII.description
desc
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
#                                 ...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: str

# %% [markdown]
# Selecting the first value of "description"

# %%
f_desc = reviewsII.loc[0,'description']
f_desc
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %% [markdown]
# Selecting first row of data

# %%
f_row = reviewsII.iloc[0]
f_row
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %% [markdown]
# selecting first ten values form 'description' column

# %%
desc = reviewsII.loc[:9,'description']
desc
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
#                            ...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, Length: 10, dtype: str

# %% [markdown]
# Select the records with index labels 1, 2, 3, 5, and 8

# %%
select_rec = reviewsII.iloc[[1,2,3,5,8]]
select_rec
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 5     Spain  Blackberry and raspberry aromas show a typical...
# 8   Germany  Savory dried thyme notes accent sunnier flavor...
#
#             designation  points  price        province             region_1  \
# 1              Avidagos      87   15.0           Douro                  NaN
# 2                   NaN      87   14.0          Oregon    Willamette Valley
# 3  Reserve Late Harvest      87   13.0        Michigan  Lake Michigan Shore
# 5          Ars In Vitro      87   15.0  Northern Spain              Navarra
# 8                 Shine      87   12.0     Rheinhessen                  NaN
#
#             region_2         taster_name taster_twitter_handle  \
# ...

# %% [markdown]
# Create a variable count containing the country, province, region_1, and region_2 columns of the records with the index labels 0, 1, 10, and 100

# %%
count = reviewsII.loc[[0,1,10,100],['country','province','region_1','region_2']]
count
# Out:
#       country           province      region_1      region_2
# 0       Italy  Sicily & Sardinia          Etna           NaN
# 1    Portugal              Douro           NaN           NaN
# 10         US         California   Napa Valley          Napa
# 100        US           New York  Finger Lakes  Finger Lakes

# %% [markdown]
# Create a variable hundred containing the country and variety columns of the first 100 records.

# %%
hundred = reviewsII.loc[:99,['country','variety']]
#hundredI = reviewsII.iloc[:100,[0,11]]
#iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. loc, meanwhile, indexes inclusively.
hundred
# Out:
#      country                   variety
# 0      Italy               White Blend
# 1   Portugal            Portuguese Red
# ..       ...                       ...
# 98     Italy                Sangiovese
# 99        US  Bordeaux-style Red Blend
#
# [100 rows x 2 columns]

# %% [markdown]
# Create a DataFrame italian_wines containing reviews of wines made in Italy

# %%
italian_wines = reviewsII.loc[reviewsII.country == 'Italy']
italian_wines
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %% [markdown]
# Create a DataFrame top_oceania_wines containing all reviews with at least 95 points (out of 100) for wines from Australia or New Zealand.

# %%
top_oceania_wines = reviewsII.loc[(reviewsII.points >=95) 
                                  & (reviewsII.country.isin(['Australia','New Zealand']))]
top_oceania_wines
# Out:
#             country                                        description  \
# 345       Australia  This wine contains some material over 100 year...
# 346       Australia  This deep brown wine smells like a damp, mossy...
# ...             ...                                                ...
# 122507  New Zealand  This blend of Cabernet Sauvignon (62.5%), Merl...
# 122939    Australia  Full-bodied and plush yet vibrant and imbued w...
#
#                                   designation  points  price         province  \
# 345                                      Rare     100  350.0         Victoria
# 346                                      Rare      98  350.0         Victoria
# ...                                       ...     ...    ...              ...
# 122507  SQM Gimblett Gravels Cabernets/Merlot      95   79.0      Hawke's Bay
# 122939                             The Factor      98  125.0  South Australia
#
# ...

# %% [markdown]
# <h3>Part III: Summary Functions and Maps</h3>
# Re-formatting data to get the input according to the standards

# %% [markdown]
# Mean and Median of 'points' column

# %%
mean = reviewsII.points.mean()
median = reviewsII.points.median()
median
# Out:
# np.float64(88.0)

# %%
mean
# Out:
# np.float64(88.44713820775404)

# %% [markdown]
# countries in dataset list

# %%
countries = reviewsII.country.unique()
countries
# Out:
# <StringArray>
# [                 'Italy',               'Portugal',                     'US',
#                   'Spain',                 'France',                'Germany',
#               'Argentina',                  'Chile',              'Australia',
#                 'Austria',           'South Africa',            'New Zealand',
#                  'Israel',                'Hungary',                 'Greece',
#                 'Romania',                 'Mexico',                 'Canada',
#                       nan,                 'Turkey',         'Czech Republic',
#                'Slovenia',             'Luxembourg',                'Croatia',
#                 'Georgia',                'Uruguay',                'England',
#                 'Lebanon',                 'Serbia',                 'Brazil',
#                 'Moldova',                'Morocco',                   'Peru',
#                   'India',               'Bulgaria',                 'Cyprus',
# ...

# %% [markdown]
# How often each country appears

# %%
countries_count = reviewsII.country.value_counts()
countries_count
# Out:
# country
# US        54504
# France    22093
#           ...
# China         1
# Egypt         1
# Name: count, Length: 43, dtype: int64

# %% [markdown]
# Create variable centered_price containing a version of the price column with the mean price subtracted

# %%
mean_price = reviewsII.price.mean()
centered_price = reviewsII.price - mean_price
centered_price
# Out:
# 0               NaN
# 1        -20.363389
#             ...
# 129969    -3.363389
# 129970   -14.363389
# Name: price, Length: 129971, dtype: float64

# %%
#alternative method using map() 
review_price_mean = reviewsII.price.mean()
centered_price2 = reviewsII.price.map(lambda p: p - review_price_mean)
centered_price2
# Out:
# 0               NaN
# 1        -20.363389
#             ...
# 129969    -3.363389
# 129970   -14.363389
# Name: price, Length: 129971, dtype: float64

# %% [markdown]
# Create a variable bargain_wine with the title of the wine with the highest points-to-price ratio in the dataset.

# %%
bargain_wine = reviewsII.loc[(reviewsII.points/reviewsII.price).idxmax(), 'title']
bargain_wine
# Out:
# 'Bandit NV Merlot (California)'

# %% [markdown]
# Is a wine more likely to be "tropical" or "fruity"? Create a Series descriptor_counts counting how many times each of these two words appears in the description column in the dataset. (For simplicity, let's ignore the capitalized versions of these words.)

# %%
tropical_count = reviewsII.description.map(lambda b: "tropical" in b).sum()
fruity_count = reviewsII.description.map(lambda b: "fruity" in b).sum()

descriptor_count = pd.Series([tropical_count,fruity_count], index = ['tropical','fruity'], name = 'countor')
descriptor_count
# Out:
# tropical    3607
# fruity      9090
# Name: countor, dtype: int64

# %% [markdown]
# We'd like to host these wine reviews on our website, but a rating system ranging from 80 to 100 points is too hard to understand - we'd like to translate them into simple star ratings. A score of 95 or higher counts as 3 stars, a score of at least 85 but less than 95 is 2 stars. Any other score is 1 star.
#
# Also, the Canadian Vintners Association bought a lot of ads on the site, so any wines from Canada should automatically get 3 stars, regardless of points.
#
# Create a series star_ratings with the number of stars corresponding to each review in the dataset.

# %%
def stars(row):
    if row.country == "Canada":
        return 3
    elif row.points>=95:
        return 3
    elif row.points >= 85:
        return 2
    else:
        return 1

star_ratings = reviewsII.apply(stars, axis=1)
star_ratings
# Out:
# 0         2
# 1         2
#          ..
# 129969    2
# 129970    2
# Length: 129971, dtype: int64

# %% [markdown]
# <h3>Part IV: Grouping and Sorting</h3>

# %%
#Create a `Series` whose index is the `taster_twitter_handle` category from the dataset, 
#and whose values count how many reviews each person wrote.

taster_count = reviewsII.groupby('taster_twitter_handle').taster_twitter_handle.count()
taster_count
# Out:
# taster_twitter_handle
# @AnneInVino        3685
# @JoeCz             5147
#                    ...
# @winewchristina       6
# @worldwineguys     1005
# Name: taster_twitter_handle, Length: 15, dtype: int64

# %%
# Create a Series whose index is wine prices and whose values is the maximum number of points a wine costing that much was given in a review. Sort the values by price, ascending (so that 4.0 dollars is at the top and 3300.0 dollars is at the bottom).
points = reviewsII.groupby('price')['points'].max().sort_index()
points
# Out:
# price
# 4.0       86
# 5.0       87
#           ..
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
#What are the minimum and maximum prices for each variety of wine? Create a DataFrame whose index is the variety category from the dataset and whose values are the min and max values thereof.
min_max = reviewsII.groupby('variety').price.agg([min,max])
min_max
# Out:
#               min   max
# variety
# Abouriou     15.0  75.0
# Agiorgitiko  10.0  66.0
# ...           ...   ...
# Çalkarası    19.0  19.0
# Žilavka      15.0  15.0
#
# [707 rows x 2 columns]

# %%
#What are the most expensive wine varieties? Create a variable sorted_varieties containing a copy of the dataframe from the previous question where varieties are sorted in descending order based on minimum price, then on maximum price (to break ties).
exp_wine = min_max.sort_values(by = ['min','max'], ascending = False)

exp_wine.head()
# Out:
#                     min    max
# variety
# Ramisco           495.0  495.0
# Terrantez         236.0  236.0
# Francisa          160.0  160.0
# Rosenmuskateller  150.0  150.0
# Tinta Negra Mole  112.0  112.0

# %%
#Create a Series whose index is reviewers and whose values is the average review score given out by that reviewer. Hint: you will need the taster_name and points columns.
reviewers_mean_rating = reviewsII.groupby('taster_name').points.mean()
reviewers_mean_rating
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
#                         ...
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, Length: 19, dtype: float64

# %%
#to see summary of the range of values from above
reviewers_mean_rating.describe()
# Out:
# count    19.000000
# mean     88.233026
#            ...
# 75%      88.975256
# max      90.562551
# Name: points, Length: 8, dtype: float64

# %%
#What combination of countries and varieties are most common? Create a Series whose index is a MultiIndexof {country, variety} pairs.
#For example, a pinot noir produced in the US should map to {"US", "Pinot Noir"}. Sort the values in the Series in descending order 
#based on wine count.

countries_varieties = reviewsII.groupby(['country','variety']).size().sort_values(ascending=False)
countries_varieties
# Out:
# country  variety
# US       Pinot Noir            9885
#          Cabernet Sauvignon    7315
#                                ...
# Italy    Catalanesca              1
#          Carmenère                1
# Length: 1612, dtype: int64

# %% [markdown]
# <h3>Part V: Data Types and Missing Values</h3>

# %%
#to see datatype of a column

dtype = reviewsII.points.dtype
dtype
# Out:
# dtype('int64')

# %%
#Create a Series from entries in the points column, but convert the entries to strings

int64_to_str = reviewsII.points.astype(str)
int64_to_str
# Out:
# 0         87
# 1         87
#           ..
# 129969    90
# 129970    90
# Name: points, Length: 129971, dtype: str

# %%
#check how many values are null in a column

missing_values = reviewsII[pd.isnull(reviewsII.price)]
total_missing = len(missing_values)

total_missing

#total_missing = reviewsII.price.isnull().sum()  //This can also be used//
# Out:
# 8996

# %%
#Create a Series counting the number of times each value occurs in the region_1 field. 
# This field is often missing data, so replace missing values with Unknown. Sort in descending order.

reviews_per_region = reviewsII.region_1.fillna("Unknown").value_counts()

reviews_per_region
# Out:
# region_1
# Unknown                21247
# Napa Valley             4480
#                        ...
# Bardolino Superiore        1
# Paestum                    1
# Name: count, Length: 1230, dtype: int64
